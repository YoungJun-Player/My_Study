# %% [markdown]
# # 01-1-2 빅데이터 가치

# %% [markdown]
# ## 1. 빅데이터 가치

# %% [markdown]
# 빅데이터를 통해서 기업 / 조직의 불확실성 제거, 리스크 감소, 스마트한 경쟁력, 타 분야 융합으로 가치를 창출할 수 있다

# %% [markdown]
# -  경제적 자산 : 새로운 기회를 창출하고 위험을 해결하여 사회 및 경제 발전의 엔진 역할 수행
#
# - 불확실성 제거 : 사회현상과 현실 세계의 데이터 기반으로한 패턴 분석과 미래 전망, 여러가지 가능성에 대한 시나리오 시뮬레이션
#
# - 리스크 감소 : 패턴 분석을 통해 위험 징후 및 이상 신호 포착, 이슈를 사전에 인지 및 분석하고 빠른 의사 결정과 실시간 대응
#
# - 스마트한 경쟁력 :  대규모 데이터 분석을 통한 상황인지와 인공지능 서비스, 개인화와 지능화 서비스 제공 확대, 트렌드 변화 분석을 통한 제품 경쟁력 확보
#
# - 타 분야 융합 : 타 분야와의 융합을 통한 새로운 가치 창출, 방대한 데이터 활용을 통한 새로운 융합시장 창출

# %% [markdown]
# ## 2. 빅데이터 가치 산정이 어려운 이유

# %% [markdown]
# - 데이터 활용 방식 : 데이터의 창의적 조합으로 인해 기존에 풀 수 없는 문제를 해결하는 데 도움을 주기 때문에 가치 산정이 어려움
#
# - 새로운 가치 창출 : 빅데이터 시대에 데이터가  기존에 없던 가치를 창출하여 가치 산정이 어려움
#
# - 분석기술의 급속한 발전 : 비용 문제로 인해 분석할 수 없었던 것을 저렴한 비용으로 분석하면서 활용도가 증가하여 가치산정이 어려움

# %% [markdown]
# ## 3. 빅데이터 영향

# %% [markdown]
# #### 기업
#
# 혁신 수당 제공, 경쟁력 강화, 생산성 향상
#
# 소비자의 행동을 분석하고 시장 변동을 예측해서 비즈니스 모델을 혁신하거나 신사업을 발굴
#
# 원가 절감, 제품 차별화, 기업 활동의 투명성 제고 등을 활용하여 경쟁사보다 경쟁 우위를 확보

# %% [markdown]
# #### 정부
#
# 환경 탐색, 상황 분석, 미래 대응 가능
#
# 날씨, 교통 등 통계 데이터를 수집해 사회 변화를 추정하고 각종 재해 관련 정보를 추출
#
# 사회 연결망 분석, 시스템 다이내믹스와 같은 분석 방식을 통해 미래 의제 도출

# %% [markdown]
# #### 개인
#
# 목적에 따른 활용
#
# 빅데이터 서비스를 저렴한 비용으로 활용
#
# 적시에 필요한 정보를 획득

# %% [markdown]
# ## 4. 빅데이터 위기 요인 및 통제 방안

# %% [markdown]
# ### 가. 빅데이터 위기 요인

# %% [markdown]
# #### 사생활 침해
#
# 목적 외로 활용된 개인 정보가 포함된 데이터의 경우 사생활 침해를 넘어 사회, 경제적 위협으로 확대

# %% [markdown]
# #### 책임 원칙 훼손
#
# 분석 대상이 되는 사람들이 예측 알고리즘의 희생자가 될 가능성도 증가
#
# 잠재적 위협이 아닌 명확한 결과에 대한 책임을 묻고 있는 민주주의 국가 원리를 훼손할 가능성 존재

# %% [markdown]
# #### 데이터 오용
#
# 데이터 분석은 실제 일어난 일에 대한 데이터에 의존하기 때문에 이를 바탕으로 미래를 예측하는 것은 언제나 맞을 수는 없는 오류가 존재함
#
# 잘못된 지표를 사용하는 것도 빅데이터의 피해가 될 수 있음

# %% [markdown]
# ### 나. 빅데이터 위기 요인에 대한 통제 방안

# %% [markdown]
# #### 책임의 강조
#
# 사생활 침해
#
# 개인정보를 사용하는 사용자의 책임을 통해 해결
#
# 동의 없는 사용으로 발생하는 피해의 책임을 지게 함

# %% [markdown]
# #### 결과 기반의 책임 적용
#
# 책임 원칙 훼손
#
# 오류가 있는 예측 알고리즘을 통해서는 불이익을 줄 수 없으며, 방지를 위한 피해 최소화 장치 마련 필요

# %% [markdown]
# #### 알고리즘에 대한 접근 허용
#
# 데이터 오용
#
# 부당함을 반증할 수 있는 알고리즘에 대한 접근권 제공
#
# 알고리즘을 통해 불이익을 당한 사람들을 대변한 알고리즈미스트라는 전문가가 필요

# %% [markdown]
# ## 5. 분석 가치 에스컬레이터

# %% [markdown]
# 가트너가 빅데이터의 가치를 4가지로 정의한 방법
#
# 높은 난도를 수반하는 데이터 분석은 더 많은 가치를 창출

# %% [markdown]
# #### 묘사 분석
#
# 분석의 가장 기본적인 지표 확인
#
# 과거에 어떤 일이 일어났고, 현재는 무슨 일이 일어나고 있는지 확인

# %% [markdown]
# #### 진단 분석
#
# 묘사 단계에서 찾아낸 분석의 원인을 이해하는 단계
#
# 데이터를 기반으로 왜 발생했는지 이유를 확인

# %% [markdown]
# #### 예측 분석
#
# 데이터를 통해 기업 혹은 조직의 미래, 고객의 행동 등을 예측하는 단계
#
# 무슨 일이 일어날 것인지를 예측

# %% [markdown]
# #### 처방 분석
#
# 예측을 바탕으로 최적화하는 단계
#
# 무엇을 해야 할 것인지를 확인
